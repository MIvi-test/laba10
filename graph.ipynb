# %%
import pandas as pd
import seaborn as sns

# %%
f = open('data.txt').readlines()
data = {}
for i in f:
    key,value = list(map(int,i.split(' ')))
    data[key] = value

# %%
ax = sns.lineplot(data)
ax.grid(True)
